# %%
import nnunetv2
#setting the path

import os
os.environ["nnUNet_raw"] = "/home/cuixing/Foot&Ankle/Tarsus_split_rawdata"
os.environ["nnUNet_preprocessed"] = "/nfs/turbo/coe-mreedsensitive/Processing/Foot_and_Ankle/Xingyang_Cui/Data_Preprocessed"
os.environ["nnUNet_results"] = "/home/cuixing/Foot&Ankle/Results"  # 训练结果存放目录
# =Check
print("nnUNet_raw:", os.environ.get("nnUNet_raw"))
print("nnUNet_preprocessed:", os.environ.get("nnUNet_preprocessed"))
print("nnUNet_results:", os.environ.get("nnUNet_results"))
# Out:
# nnUNet_raw: /home/cuixing/Foot&Ankle/Tarsus_split_rawdata
# nnUNet_preprocessed: /nfs/turbo/coe-mreedsensitive/Processing/Foot_and_Ankle/Xingyang_Cui/Data_Preprocessed
# nnUNet_results: /home/cuixing/Foot&Ankle/Results

# %%
import subprocess
import os

# Set environment variables
env_vars = {
    "LC_ALL": "C.UTF-8",
    "LANG": "C.UTF-8"
}

command = [
    "nnUNetv2_plan_and_preprocess",
    "-d", "001",
    "-np", "6",  # number of cores
]

subprocess.run(command, env={**env_vars, **dict(os.environ)}, text=True)
# Out:
# Fingerprint extraction...
# Dataset001_TS_app_bones
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Attempting to find 3d_lowres config.
# Current spacing: [0.7725 0.7725 0.7725].
# Current patch size: (256, 96, 80).
# Current median shape: [1678.15533981  517.47572816  517.47572816]
# Attempting to find 3d_lowres config.
# Current spacing: [0.795675 0.795675 0.795675].
# Current patch size: (256, 96, 80).
# Current median shape: [1629.27702894  502.40361957  502.40361957]
# Attempting to find 3d_lowres config.
# Current spacing: [0.81954525 0.81954525 0.81954525].
# Current patch size: (256, 96, 80).
# Current median shape: [1581.82235819  487.77050444  487.77050444]
# Attempting to find 3d_lowres config.
# Current spacing: [0.84413161 0.84413161 0.84413161].
# Current patch size: (256, 96, 80).
# Current median shape: [1535.74986232  473.56359654  473.56359654]
# Attempting to find 3d_lowres config.
# Current spacing: [0.86945556 0.86945556 0.86945556].
# Current patch size: (256, 96, 80).
# Current median shape: [1491.01928381  459.77048208  459.77048208]
# Attempting to find 3d_lowres config.
# Current spacing: [0.89553922 0.89553922 0.89553922].
# Current patch size: (256, 96, 80).
# Current median shape: [1447.59153768  446.37910881  446.37910881]
# Attempting to find 3d_lowres config.
# Current spacing: [0.9224054 0.9224054 0.9224054].
# Current patch size: (256, 96, 80).
# Current median shape: [1405.42867736  433.37777555  433.37777555]
# Attempting to find 3d_lowres config.
# Current spacing: [0.95007756 0.95007756 0.95007756].
# Current patch size: (256, 96, 80).
# Current median shape: [1364.49386151  420.75512189  420.75512189]
# Attempting to find 3d_lowres config.
# Current spacing: [0.97857989 0.97857989 0.97857989].
# Current patch size: (256, 96, 80).
# Current median shape: [1324.75132186  408.50011834  408.50011834]
# Attempting to find 3d_lowres config.
# Current spacing: [1.00793728 1.00793728 1.00793728].
# Current patch size: (256, 96, 80).
# Current median shape: [1286.1663319   396.60205664  396.60205664]
# Attempting to find 3d_lowres config.
# Current spacing: [1.0381754 1.0381754 1.0381754].
# Current patch size: (256, 96, 80).
# Current median shape: [1248.7051766   385.05054043  385.05054043]
# Attempting to find 3d_lowres config.
# Current spacing: [1.06932067 1.06932067 1.06932067].
# Current patch size: (256, 96, 80).
# Current median shape: [1212.33512291  373.83547614  373.83547614]
# Attempting to find 3d_lowres config.
# Current spacing: [1.10140029 1.10140029 1.10140029].
# Current patch size: (256, 96, 80).
# Current median shape: [1177.02439118  362.94706422  362.94706422]
# Attempting to find 3d_lowres config.
# Current spacing: [1.13444229 1.13444229 1.13444229].
# Current patch size: (256, 96, 80).
# Current median shape: [1142.74212736  352.3757905   352.3757905 ]
# Attempting to find 3d_lowres config.
# Current spacing: [1.16847556 1.16847556 1.16847556].
# Current patch size: (256, 96, 80).
# Current median shape: [1109.45837608  342.11241796  342.11241796]
# Attempting to find 3d_lowres config.
# Current spacing: [1.20352983 1.20352983 1.20352983].
# Current patch size: (256, 96, 80).
# Current median shape: [1077.14405444  332.1479786   332.1479786 ]
# Attempting to find 3d_lowres config.
# Current spacing: [1.23963572 1.23963572 1.23963572].
# Current patch size: (256, 96, 80).
# Current median shape: [1045.77092664  322.47376564  322.47376564]
# Attempting to find 3d_lowres config.
# Current spacing: [1.2768248 1.2768248 1.2768248].
# Current patch size: (256, 96, 80).
# Current median shape: [1015.31157926  313.08132586  313.08132586]
# Attempting to find 3d_lowres config.
# Current spacing: [1.31512954 1.31512954 1.31512954].
# Current patch size: (256, 96, 80).
# Current median shape: [985.73939734 303.96245229 303.96245229]
# Attempting to find 3d_lowres config.
# Current spacing: [1.35458343 1.35458343 1.35458343].
# Current patch size: (256, 96, 80).
# Current median shape: [957.02854111 295.10917698 295.10917698]
# Attempting to find 3d_lowres config.
# Current spacing: [1.39522093 1.39522093 1.39522093].
# Current patch size: (256, 96, 80).
# Current median shape: [929.15392341 286.51376406 286.51376406]
# Attempting to find 3d_lowres config.
# Current spacing: [1.43707756 1.43707756 1.43707756].
# Current patch size: (256, 96, 80).
# Current median shape: [902.09118778 278.16870297 278.16870297]
# Attempting to find 3d_lowres config.
# Current spacing: [1.48018988 1.48018988 1.48018988].
# Current patch size: (256, 96, 80).
# Current median shape: [875.81668716 270.06670191 270.06670191]
# Attempting to find 3d_lowres config.
# Current spacing: [1.52459558 1.52459558 1.52459558].
# Current patch size: (256, 96, 80).
# Current median shape: [850.30746326 262.20068147 262.20068147]
# Attempting to find 3d_lowres config.
# Current spacing: [1.57033345 1.57033345 1.57033345].
# Current patch size: (256, 96, 80).
# Current median shape: [825.54122647 254.56376842 254.56376842]
# Attempting to find 3d_lowres config.
# Current spacing: [1.61744345 1.61744345 1.61744345].
# Current patch size: (256, 96, 80).
# Current median shape: [801.49633638 247.14928972 247.14928972]
# Attempting to find 3d_lowres config.
# Current spacing: [1.66596675 1.66596675 1.66596675].
# Current patch size: (256, 96, 80).
# Current median shape: [778.15178289 239.95076672 239.95076672]
# Attempting to find 3d_lowres config.
# Current spacing: [1.71594576 1.71594576 1.71594576].
# Current patch size: (256, 96, 80).
# Current median shape: [755.48716786 232.96190944 232.96190944]
# Attempting to find 3d_lowres config.
# Current spacing: [1.76742413 1.76742413 1.76742413].
# Current patch size: (256, 96, 80).
# Current median shape: [733.48268724 226.17661111 226.17661111]
# Attempting to find 3d_lowres config.
# Current spacing: [1.82044685 1.82044685 1.82044685].
# Current patch size: (256, 96, 80).
# Current median shape: [712.11911382 219.58894282 219.58894282]
# Attempting to find 3d_lowres config.
# Current spacing: [1.87506026 1.87506026 1.87506026].
# Current patch size: (256, 96, 80).
# Current median shape: [691.37778041 213.19314837 213.19314837]
# Attempting to find 3d_lowres config.
# Current spacing: [1.93131207 1.93131207 1.93131207].
# Current patch size: (256, 96, 80).
# Current median shape: [671.24056351 206.9836392  206.9836392 ]
# Attempting to find 3d_lowres config.
# Current spacing: [1.98925143 1.98925143 1.98925143].
# Current patch size: (256, 96, 80).
# Current median shape: [651.68986748 200.95498951 200.95498951]
# Attempting to find 3d_lowres config.
# Current spacing: [2.04892897 2.04892897 2.04892897].
# Current patch size: (256, 96, 80).
# Current median shape: [632.70860921 195.10193156 195.10193156]
# Attempting to find 3d_lowres config.
# Current spacing: [2.11039684 2.11039684 2.11039684].
# Current patch size: (256, 96, 80).
# Current median shape: [614.28020311 189.41935103 189.41935103]
# Attempting to find 3d_lowres config.
# Current spacing: [2.17370875 2.17370875 2.17370875].
# Current patch size: (256, 96, 80).
# Current median shape: [596.38854671 183.90228256 183.90228256]
# Attempting to find 3d_lowres config.
# Current spacing: [2.23892001 2.23892001 2.23892001].
# Current patch size: (256, 96, 80).
# Current median shape: [579.01800652 178.54590539 178.54590539]
# Attempting to find 3d_lowres config.
# Current spacing: [2.30608761 2.30608761 2.30608761].
# Current patch size: (256, 96, 80).
# Current median shape: [562.15340438 173.34553922 173.34553922]
# Attempting to find 3d_lowres config.
# Current spacing: [2.37527024 2.37527024 2.37527024].
# Current patch size: (256, 96, 80).
# Current median shape: [545.78000426 168.29664002 168.29664002]
# Attempting to find 3d_lowres config.
# Current spacing: [2.44652834 2.44652834 2.44652834].
# Current patch size: (256, 96, 80).
# Current median shape: [529.88349928 163.39479613 163.39479613]
# Attempting to find 3d_lowres config.
# Current spacing: [2.51992419 2.51992419 2.51992419].
# Current patch size: (256, 96, 80).
# Current median shape: [514.4499993 158.6357244 158.6357244]
# Attempting to find 3d_lowres config.
# Current spacing: [2.59552192 2.59552192 2.59552192].
# Current patch size: (256, 96, 80).
# Current median shape: [499.46601874 154.01526641 154.01526641]
# Attempting to find 3d_lowres config.
# Current spacing: [2.67338758 2.67338758 2.67338758].
# Current patch size: (256, 96, 80).
# Current median shape: [484.91846479 149.52938486 149.52938486]
# Attempting to find 3d_lowres config.
# Current spacing: [2.75358921 2.75358921 2.75358921].
# Current patch size: (256, 96, 80).
# Current median shape: [470.79462601 145.17416006 145.17416006]
# Attempting to find 3d_lowres config.
# Current spacing: [2.83619688 2.83619688 2.83619688].
# Current patch size: (256, 96, 80).
# Current median shape: [457.08216118 140.94578647 140.94578647]
# Attempting to find 3d_lowres config.
# Current spacing: [2.92128279 2.92128279 2.92128279].
# Current patch size: (256, 96, 80).
# Current median shape: [443.76908852 136.84056938 136.84056938]
# Attempting to find 3d_lowres config.
# Current spacing: [3.00892127 3.00892127 3.00892127].
# Current patch size: (256, 96, 80).
# Current median shape: [430.84377526 132.85492173 132.85492173]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 7, 'patch_size': (640, 640), 'median_image_size_in_voxels': array([533., 533.]), 'spacing': array([0.75, 0.75]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 8, 'features_per_stage': (32, 64, 128, 256, 512, 512, 512, 512), 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': ((3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3)), 'strides': ((1, 1), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.nibabel_reader_writer.NibabelIOWithReorient'> reader/writer
# 3D lowres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_lowres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': (256, 96, 80), 'median_image_size_in_voxels': (431, 133, 133), 'spacing': array([3.00892127, 3.00892127, 3.00892127]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 6, 'features_per_stage': (32, 64, 128, 256, 320, 320), 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': ((3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3)), 'strides': ((1, 1, 1), (2, 2, 2), (2, 2, 2), (2, 2, 2), (2, 2, 2), (2, 1, 1)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': False, 'next_stage': '3d_cascade_fullres'}
#
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': (256, 96, 80), 'median_image_size_in_voxels': array([1728.5,  533. ,  533. ]), 'spacing': array([0.75, 0.75, 0.75]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 6, 'features_per_stage': (32, 64, 128, 256, 320, 320), 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': ((3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3)), 'strides': ((1, 1, 1), (2, 2, 2), (2, 2, 2), (2, 2, 2), (2, 2, 2), (2, 1, 1)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Plans were saved to /nfs/turbo/coe-mreedsensitive/Processing/Foot_and_Ankle/Xingyang_Cui/Data_Preprocessed/Dataset001_TS_app_bones/nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset001_TS_app_bones
# Configuration: 2d...
# 100%|██████████| 12/12 [06:06<00:00, 30.51s/it]
# Configuration: 3d_fullres...
# 100%|██████████| 12/12 [06:05<00:00, 30.46s/it]
# Configuration: 3d_lowres...
#  92%|█████████▏| 11/12 [07:45<00:26, 27.00s/it]
